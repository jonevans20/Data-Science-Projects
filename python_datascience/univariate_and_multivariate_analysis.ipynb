# %%
import seaborn as sns
diamonds = sns.load_dataset('diamonds')

# %%
import pandas as pd 
import numpy as np  
import scipy as sc 
import matplotlib as mat

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
print(diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds[diamonds['price']>1500]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 90      0.70      Ideal     E     SI1   62.5   57.0   2757  5.70  5.72  3.57
# 91      0.86       Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 92      0.70      Ideal     G     VS2   61.6   56.0   2757  5.70  5.67  3.50
# 93      0.71  Very Good     E     VS2   62.4   57.0   2759  5.68  5.73  3.56
# 94      0.78  Very Good     G     SI2   63.8   56.0   2759  5.81  5.85  3.72
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [33930 rows x 10 columns]

# %%
diamonds['price'].plot.area()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1394003/1814235436.py in <module>
# ----> 1 diamonds['price'].plot.area()
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in area(self, x, y, **kwargs)
#    1306             >>> ax = df.plot.area(x='day')
#    1307         """
# -> 1308         return self(kind="area", x=x, y=y, **kwargs)
#    1309
#    1310     def pie(self, **kwargs):
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# /usr/lib/python3/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
diamonds.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object
